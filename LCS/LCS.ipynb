# %%
import matplotlib.pyplot as plt
import pandas as pd

# Function to read data from CSV files and plot execution times
def plot_lcs_execution_time(c_file, cpp_file):
    c_data = pd.read_csv(c_file)
    cpp_data = pd.read_csv(cpp_file)

    plt.figure(figsize=(10, 6))

    plt.plot(c_data['i'], c_data['time'], label='C', color='b', marker='o')

    plt.plot(cpp_data['i'], cpp_data['time'], label='C++', color='r', marker='x')

    plt.xlabel('String Length (i)', fontsize=12)
    plt.ylabel('Execution Time (seconds)', fontsize=12)
    plt.title('LCS Execution Time Comparison: C vs C++', fontsize=14)
    
    plt.legend()

    plt.xscale('log')
    plt.yscale('log')

    plt.savefig('lcs_execution_time_comparison.png')

    plt.show()

# %%
c_file = 'lcs_results.csv'  
cpp_file = 'lcs_cpp_results.csv' 
plot_lcs_execution_time(c_file, cpp_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\E15\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\E15\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\E15\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'i'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 c_file = 'lcs_results.csv'
#       2 cpp_file = 'lcs_cpp_results.csv'
# ----> 3 plot_lcs_execution_time(c_file, cpp_file)
#
# Cell In[2], line 13, in plot_lcs_execution_time(c_file, cpp_file)
#       9 plt.figure(figsize=(10, 6))
#      11 plt.plot(c_data['i'], c_data['time'], label='C', color='b', marker='o')
# ---> 13 plt.plot(cpp_data['i'], cpp_data['time'], label='C++', color='r', marker='x')
#      15 plt.xlabel('String Length (i)', fontsize=12)
#      16 plt.ylabel('Execution Time (seconds)', fontsize=12)
#
# File c:\Users\E15\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\E15\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'i'
